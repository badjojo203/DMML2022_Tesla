# %% [markdown]
# import packages

# %%
import wheel
import fasttext
import pandas as pd
import numpy as np

# %% [markdown]
# import data

# %%
df = pd.read_csv('../data/training_data.csv')

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
labelencoder = LabelEncoder()
df['le_difficulty'] = labelencoder.fit_transform(df['difficulty'])
df.head(5)

X = df["sentence"]
y = df["le_difficulty"]
# best test size for linera
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.02416669999999996, random_state=5)

# %%
def evaluate(true, pred):
    precision = precision_score(y_test, y_pred, average="macro")
    recall = recall_score(y_test, y_pred, average="macro")
    f1 = f1_score(y_test, y_pred, average="macro")
    print(f"CONFUSION MATRIX:\n{confusion_matrix(true, pred)}")
    print(f"ACCURACY SCORE:\n{accuracy_score(true, pred):.4f}")
    print(f"CLASSIFICATION REPORT:\n\tPrecision: {precision:.4f}\n\tRecall: {recall:.4f}\n\tF1_Score: {f1:.4f}")

# %% [markdown]
# Cleaners

# %%
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
#nltk.download('punkt')

# Fonction pour enlever les mots inutiles (stop words) d'une phrase
def remove_stop_words(sentence):
    # Tokeniser la phrase et enlever les stop words
    words = nltk.word_tokenize(sentence)
    filtered_words = [word for word in words if word not in stopwords.words('french')]

    # Rejoindre les mots filtrés en une phrase
    return ' '.join(filtered_words)



# Fonction pour lemmatiser les mots d'une phrase
def lemmatize(sentence):
    # Tokeniser la phrase et lemmatiser les mots
    words = nltk.word_tokenize(sentence)
    lemmatizer = WordNetLemmatizer()
    lemmas = [lemmatizer.lemmatize(word) for word in words]

    # Rejoindre les lemmas en une phrase
    return ' '.join(lemmas)

def data_cleaner(sms):

    # Define stopwords
    stop_words = stopwords.words('french')

    # Define tokenizer and stemmer
    from nltk.tokenize import word_tokenize
    from nltk.stem import PorterStemmer

    # Remove digits
    sms = re.sub(r"\d+","", sms)

    # Lowercase
    sms = sms.lower()

    # Remove punctuation
    sms = str(re.sub(r"[^\w\s\d]","", sms))

    # Remove stop words
    sms = sms.split()
    sms = " ".join([word for word in sms if not word in stop_words])

    # Tokenize
    sms = word_tokenize(sms)

    # Stemming
    ps = PorterStemmer()
    sms = [ps.stem(word) for word in sms]

    return str(sms)

def empty(sentence):

    return sentence

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer, HashingVectorizer, TfidfVectorizer
# Combining the three models into an ensemble
from sklearn.ensemble import VotingClassifier

# %%
# Définir les méthodes de vectorisation, de classification et de nettoyage de données à tester
#vectorizers = [CountVectorizer(), TfidfVectorizer(), HashingVectorizer()]
#classifiers = [LogisticRegression(max_iter=1000,solver="lbfgs",random_state=50), KNeighborsClassifier(n_neighbors=5),SVC()]
#cleaners = [data_cleaner,remove_stop_words, lemmatize]

vectorizers = [TfidfVectorizer()]
classifiers = [LinearSVC()]
cleaners = [empty]

# %%
estimators = []
for clf in classifiers:
    estimators.append((clf.__class__.__name__,clf))

#classifiers.append((VotingClassifier(estimators=estimators, voting='hard')))

# %%
def otpimize_test_size(X,y,method,parameter_grid):
    results = []

    #print("iterations : "+str(parameter_grid["test_size"]))
    for test_size in parameter_grid["test_size"]:
        X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=test_size, random_state=0)

        tfidf = TfidfVectorizer()
        X_train = tfidf.fit_transform(X_train)
        X_test = tfidf.transform(X_test)

        method.fit(X_train,y_train)

        y_pred = method.predict(X_test)

        score = accuracy_score(y_test,y_pred)


        results.append({
            "test_size":test_size,
            "score":score,
        })

    results.sort(key=lambda x: x["score"],reverse=True)

    best_params = {"test_size":results[0]["test_size"]}
    best_score = results[0]['score']

    return best_params,best_score

def otpimize_randomstate(X,y,method,parameter_grid,test_size):
    results = []

    #print("iterations : "+str(parameter_grid["test_size"]))
    for random_state in parameter_grid["random_state"]:
        X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=test_size, random_state=random_state)

        tfidf = TfidfVectorizer()
        X_train = tfidf.fit_transform(X_train)
        X_test = tfidf.transform(X_test)

        method.fit(X_train,y_train)

        y_pred = method.predict(X_test)

        score = accuracy_score(y_test,y_pred)


        results.append({
            "random_state":random_state,
            "score":score,
        })

    results.sort(key=lambda x: x["score"],reverse=True)

    best_params = {"random_state":results[0]["random_state"]}
    best_score = results[0]['score']

    return best_params,best_score

# %% [markdown]
# SEARCH BEST TEST SIZE PARAM

# %%
grid = {"test_size": np.arange(0.081,0.082,0.0001)}

#best param

best_param, best_score = otpimize_test_size(X,y,classifiers[0],grid)
print("best param ", best_param["test_size"])
print("best score ", best_score)
# Out:
# c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# best param  0.081
# best score  0.5218508997429306

# %%
grid = {"test_size": np.arange(0.03,0.035,0.0001)}

#best param 0.03291999999999988

best_param, best_score = otpimize_test_size(X,y,MultinomialNB(),grid)
print("best param ", best_param["test_size"])
print("best score ", best_score)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[76], line 5
#       1 grid = {"test_size": np.arange(0.03,0.035,0.0001)}
#       3 #best param 0.03291999999999988
# ----> 5 best_param, best_score = otpimize_test_size(X,y,MultinomialNB(),grid)
#       6 print("best param ", best_param["test_size"])
#       7 print("best score ", best_score)
#
# Cell In[75], line 9, in otpimize_test_size(X, y, method, parameter_grid)
#       6 X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=test_size, random_state=0)
#       8 tfidf = TfidfVectorizer()
# ----> 9 X_train = tfidf.fit_transform(X_train)
#      10 X_test = tfidf.transform(X_test)
#      12 method.fit(X_train,y_train)
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\feature_extraction\text.py:1846, in TfidfVectorizer.fit_transform(self, raw_documents, y)
#    1828 """Learn vocabulary and idf, return document-term matrix.
#    1829
#    1830 This is equivalent to fit followed by transform, but more efficiently
#    (...)
#    1843     Tf-idf-weighted document-term matrix.
#    1844 """
#    1845 self._check_params()
# -> 1846 X = super().fit_transform(raw_documents)
#    1847 self._tfidf.fit(X)
#    1848 # X is already a transformed view of raw_documents so
#    1849 # we set copy to False
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\feature_extraction\text.py:1202, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1199 min_df = self.min_df
#    1200 max_features = self.max_features
# -> 1202 vocabulary, X = self._count_vocab(raw_documents,
#    1203                                   self.fixed_vocabulary_)
#    1205 if self.binary:
#    1206     X.data.fill(1)
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\feature_extraction\text.py:1114, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1112 for doc in raw_documents:
#    1113     feature_counter = {}
# -> 1114     for feature in analyze(doc):
#    1115         try:
#    1116             feature_idx = vocabulary[feature]
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\feature_extraction\text.py:99, in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#      77 """Chain together an optional series of text processing steps to go from
#      78 a single document to ngrams, with or without tokenizing or preprocessing.
#      79
#    (...)
#      95     A sequence of tokens, possibly with pairs, triples, etc.
#      96 """
#      98 if decoder is not None:
# ---> 99     doc = decoder(doc)
#     100 if analyzer is not None:
#     101     doc = analyzer(doc)
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\feature_extraction\text.py:191, in _VectorizerMixin.decode(self, doc)
#     187 """Provides common code for text vectorizers (tokenization logic)."""
#     189 _white_spaces = re.compile(r"\s\s+")
# --> 191 def decode(self, doc):
#     192     """Decode the input into a string of unicode symbols.
#     193
#     194     The decoding strategy depends on the vectorizer parameters.
#    (...)
#     204         A string of unicode symbols.
#     205     """
#     206     if self.input == 'filename':
#
# KeyboardInterrupt:

# %%
grid = {"test_size": np.arange(0.024166,0.024267,0.0000001)}

# best param 0.02416669999999996

best_param, best_score, best_precision = otpimize_test_size(X,y,LinearSVC(),grid)
print("best param ", best_param["test_size"])
print("best score ", best_score)
print("best precision", best_precision)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 5
#       1 grid = {"test_size": np.arange(0.024166,0.024267,0.0000001)}
#       3 # best param 0.02416669999999996
# ----> 5 best_param, best_score, best_precision = otpimize_test_size(X,y,LinearSVC(),grid)
#       6 print("best param ", best_param["test_size"])
#       7 print("best score ", best_score)
#
# Cell In[27], line 12, in otpimize_test_size(X, y, method, parameter_grid)
#       9 X_train = tfidf.fit_transform(X_train)
#      10 X_test = tfidf.transform(X_test)
# ---> 12 method.fit(X_train,y_train)
#      14 y_pred = method.predict(X_test)
#      16 score = accuracy_score(y_test,y_pred)
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\svm\_classes.py:234, in LinearSVC.fit(self, X, y, sample_weight)
#     231 check_classification_targets(y)
#     232 self.classes_ = np.unique(y)
# --> 234 self.coef_, self.intercept_, self.n_iter_ = _fit_liblinear(
#     235     X, y, self.C, self.fit_intercept, self.intercept_scaling,
#     236     self.class_weight, self.penalty, self.dual, self.verbose,
#     237     self.max_iter, self.tol, self.random_state, self.multi_class,
#     238     self.loss, sample_weight=sample_weight)
#     240 if self.multi_class == "crammer_singer" and len(self.classes_) == 2:
#     241     self.coef_ = (self.coef_[1] - self.coef_[0]).reshape(1, -1)
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\svm\_base.py:975, in _fit_liblinear(X, y, C, fit_intercept, intercept_scaling, class_weight, penalty, dual, verbose, max_iter, tol, random_state, multi_class, loss, epsilon, sample_weight)
#     971 sample_weight = _check_sample_weight(sample_weight, X,
#     972                                      dtype=np.float64)
#     974 solver_type = _get_liblinear_solver_type(multi_class, penalty, loss, dual)
# --> 975 raw_coef_, n_iter_ = liblinear.train_wrap(
#     976     X, y_ind, sp.isspmatrix(X), solver_type, tol, bias, C,
#     977     class_weight_, max_iter, rnd.randint(np.iinfo('i').max),
#     978     epsilon, sample_weight)
#     979 # Regarding rnd.randint(..) in the above signature:
#     980 # seed for srand in range [0..INT_MAX); due to limitations in Numpy
#     981 # on 32-bit platforms, we can't get to the UINT_MAX limit that
#     982 # srand supports
#     983 n_iter_ = max(n_iter_)
#
# KeyboardInterrupt:

# %%
grid = {"random_state": np.arange(0,50)}

# best param 0.02416669999999996

best_param, best_score = otpimize_randomstate(X,y,LinearSVC(),grid,0.02416669999999996)
print("best param ", best_param["random_state"])
print("best score ", best_score)
# Out:
# best param  5
# best score  0.5982905982905983

# %%
grid = {"test_size": np.arange(0.01,1,0.01)}

# best param 0.023999999999999987

best_param, best_score = otpimize_test_size(X,y,LinearSVC(),grid)
print("best param ", best_param["test_size"])
print("best score ", best_score)
# Out:
# c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 5
#       1 grid = {"test_size": np.arange(0.01,1,0.001)}
#       3 # best param 0.023999999999999987
# ----> 5 best_param, best_score = otpimize_test_size(X,y,LinearSVC(),grid)
#       6 print("best param ", best_param["test_size"])
#       7 print("best score ", best_score)
#
# Cell In[40], line 9, in otpimize_test_size(X, y, method, parameter_grid)
#       6 X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=test_size, random_state=0)
#       8 tfidf = TfidfVectorizer()
# ----> 9 X_train = tfidf.fit_transform(X_train)
#      10 X_test = tfidf.transform(X_test)
#      12 method.fit(X_train,y_train)
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\feature_extraction\text.py:1846, in TfidfVectorizer.fit_transform(self, raw_documents, y)
#    1828 """Learn vocabulary and idf, return document-term matrix.
#    1829
#    1830 This is equivalent to fit followed by transform, but more efficiently
#    (...)
#    1843     Tf-idf-weighted document-term matrix.
#    1844 """
#    1845 self._check_params()
# -> 1846 X = super().fit_transform(raw_documents)
#    1847 self._tfidf.fit(X)
#    1848 # X is already a transformed view of raw_documents so
#    1849 # we set copy to False
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\feature_extraction\text.py:1202, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1199 min_df = self.min_df
#    1200 max_features = self.max_features
# -> 1202 vocabulary, X = self._count_vocab(raw_documents,
#    1203                                   self.fixed_vocabulary_)
#    1205 if self.binary:
#    1206     X.data.fill(1)
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\feature_extraction\text.py:1150, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1147 indptr = np.asarray(indptr, dtype=indices_dtype)
#    1148 values = np.frombuffer(values, dtype=np.intc)
# -> 1150 X = sp.csr_matrix((values, j_indices, indptr),
#    1151                   shape=(len(indptr) - 1, len(vocabulary)),
#    1152                   dtype=self.dtype)
#    1153 X.sort_indices()
#    1154 return vocabulary, X
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\scipy\sparse\compressed.py:73, in _cs_matrix.__init__(self, arg1, shape, dtype, copy)
#      70     self.indices = np.array(indices, copy=copy,
#      71                             dtype=idx_dtype)
#      72     self.indptr = np.array(indptr, copy=copy, dtype=idx_dtype)
# ---> 73     self.data = np.array(data, copy=copy, dtype=dtype)
#      74 else:
#      75     raise ValueError("unrecognized {}_matrix "
#      76                      "constructor usage".format(self.format))
#
# KeyboardInterrupt:

# %%
grid = {"test_size": np.arange(0.01,1,0.001)}

# best param

best_param, best_score = otpimize_test_size(X,y,LogisticRegression(max_iter=1000,solver="lbfgs",random_state=0),grid)
print("best param ", best_param["test_size"])
print("best score ", best_score)
# Out:
# iterations : [0.01  0.011 0.012 0.013 0.014 0.015 0.016 0.017 0.018 0.019 0.02  0.021
#  0.022 0.023 0.024 0.025 0.026 0.027 0.028 0.029 0.03  0.031 0.032 0.033
#  0.034 0.035 0.036 0.037 0.038 0.039 0.04  0.041 0.042 0.043 0.044 0.045
#  0.046 0.047 0.048 0.049 0.05  0.051 0.052 0.053 0.054 0.055 0.056 0.057
#  0.058 0.059 0.06  0.061 0.062 0.063 0.064 0.065 0.066 0.067 0.068 0.069
#  0.07  0.071 0.072 0.073 0.074 0.075 0.076 0.077 0.078 0.079 0.08  0.081
#  0.082 0.083 0.084 0.085 0.086 0.087 0.088 0.089 0.09  0.091 0.092 0.093
#  0.094 0.095 0.096 0.097 0.098 0.099 0.1   0.101 0.102 0.103 0.104 0.105
#  0.106 0.107 0.108 0.109 0.11  0.111 0.112 0.113 0.114 0.115 0.116 0.117
#  0.118 0.119 0.12  0.121 0.122 0.123 0.124 0.125 0.126 0.127 0.128 0.129
#  0.13  0.131 0.132 0.133 0.134 0.135 0.136 0.137 0.138 0.139 0.14  0.141
#  0.142 0.143 0.144 0.145 0.146 0.147 0.148 0.149 0.15  0.151 0.152 0.153
#  0.154 0.155 0.156 0.157 0.158 0.159 0.16  0.161 0.162 0.163 0.164 0.165
#  0.166 0.167 0.168 0.169 0.17  0.171 0.172 0.173 0.174 0.175 0.176 0.177
#  0.178 0.179 0.18  0.181 0.182 0.183 0.184 0.185 0.186 0.187 0.188 0.189
#  0.19  0.191 0.192 0.193 0.194 0.195 0.196 0.197 0.198 0.199 0.2   0.201
#  0.202 0.203 0.204 0.205 0.206 0.207 0.208 0.209 0.21  0.211 0.212 0.213
#  0.214 0.215 0.216 0.217 0.218 0.219 0.22  0.221 0.222 0.223 0.224 0.225
#  0.226 0.227 0.228 0.229 0.23  0.231 0.232 0.233 0.234 0.235 0.236 0.237
#  0.238 0.239 0.24  0.241 0.242 0.243 0.244 0.245 0.246 0.247 0.248 0.249
#  0.25  0.251 0.252 0.253 0.254 0.255 0.256 0.257 0.258 0.259 0.26  0.261
#  0.262 0.263 0.264 0.265 0.266 0.267 0.268 0.269 0.27  0.271 0.272 0.273
#  0.274 0.275 0.276 0.277 0.278 0.279 0.28  0.281 0.282 0.283 0.284 0.285
#  0.286 0.287 0.288 0.289 0.29  0.291 0.292 0.293 0.294 0.295 0.296 0.297
#  0.298 0.299 0.3   0.301 0.302 0.303 0.304 0.305 0.306 0.307 0.308 0.309
#  0.31  0.311 0.312 0.313 0.314 0.315 0.316 0.317 0.318 0.319 0.32  0.321
#  0.322 0.323 0.324 0.325 0.326 0.327 0.328 0.329 0.33  0.331 0.332 0.333
#  0.334 0.335 0.336 0.337 0.338 0.339 0.34  0.341 0.342 0.343 0.344 0.345
#  0.346 0.347 0.348 0.349 0.35  0.351 0.352 0.353 0.354 0.355 0.356 0.357
#  0.358 0.359 0.36  0.361 0.362 0.363 0.364 0.365 0.366 0.367 0.368 0.369
#  0.37  0.371 0.372 0.373 0.374 0.375 0.376 0.377 0.378 0.379 0.38  0.381
#  0.382 0.383 0.384 0.385 0.386 0.387 0.388 0.389 0.39  0.391 0.392 0.393
#  0.394 0.395 0.396 0.397 0.398 0.399 0.4   0.401 0.402 0.403 0.404 0.405
#  0.406 0.407 0.408 0.409 0.41  0.411 0.412 0.413 0.414 0.415 0.416 0.417
#  0.418 0.419 0.42  0.421 0.422 0.423 0.424 0.425 0.426 0.427 0.428 0.429
#  0.43  0.431 0.432 0.433 0.434 0.435 0.436 0.437 0.438 0.439 0.44  0.441
#  0.442 0.443 0.444 0.445 0.446 0.447 0.448 0.449 0.45  0.451 0.452 0.453
#  0.454 0.455 0.456 0.457 0.458 0.459 0.46  0.461 0.462 0.463 0.464 0.465
#  0.466 0.467 0.468 0.469 0.47  0.471 0.472 0.473 0.474 0.475 0.476 0.477
#  0.478 0.479 0.48  0.481 0.482 0.483 0.484 0.485 0.486 0.487 0.488 0.489
#  0.49  0.491 0.492 0.493 0.494 0.495 0.496 0.497 0.498 0.499 0.5   0.501
#  0.502 0.503 0.504 0.505 0.506 0.507 0.508 0.509 0.51  0.511 0.512 0.513
#  0.514 0.515 0.516 0.517 0.518 0.519 0.52  0.521 0.522 0.523 0.524 0.525
#  0.526 0.527 0.528 0.529 0.53  0.531 0.532 0.533 0.534 0.535 0.536 0.537
#  0.538 0.539 0.54  0.541 0.542 0.543 0.544 0.545 0.546 0.547 0.548 0.549
#  0.55  0.551 0.552 0.553 0.554 0.555 0.556 0.557 0.558 0.559 0.56  0.561
#  0.562 0.563 0.564 0.565 0.566 0.567 0.568 0.569 0.57  0.571 0.572 0.573
#  0.574 0.575 0.576 0.577 0.578 0.579 0.58  0.581 0.582 0.583 0.584 0.585
#  0.586 0.587 0.588 0.589 0.59  0.591 0.592 0.593 0.594 0.595 0.596 0.597
#  0.598 0.599 0.6   0.601 0.602 0.603 0.604 0.605 0.606 0.607 0.608 0.609
#  0.61  0.611 0.612 0.613 0.614 0.615 0.616 0.617 0.618 0.619 0.62  0.621
#  0.622 0.623 0.624 0.625 0.626 0.627 0.628 0.629 0.63  0.631 0.632 0.633
#  0.634 0.635 0.636 0.637 0.638 0.639 0.64  0.641 0.642 0.643 0.644 0.645
#  0.646 0.647 0.648 0.649 0.65  0.651 0.652 0.653 0.654 0.655 0.656 0.657
#  0.658 0.659 0.66  0.661 0.662 0.663 0.664 0.665 0.666 0.667 0.668 0.669
#  0.67  0.671 0.672 0.673 0.674 0.675 0.676 0.677 0.678 0.679 0.68  0.681
#  0.682 0.683 0.684 0.685 0.686 0.687 0.688 0.689 0.69  0.691 0.692 0.693
#  0.694 0.695 0.696 0.697 0.698 0.699 0.7   0.701 0.702 0.703 0.704 0.705
#  0.706 0.707 0.708 0.709 0.71  0.711 0.712 0.713 0.714 0.715 0.716 0.717
#  0.718 0.719 0.72  0.721 0.722 0.723 0.724 0.725 0.726 0.727 0.728 0.729
#  0.73  0.731 0.732 0.733 0.734 0.735 0.736 0.737 0.738 0.739 0.74  0.741
#  0.742 0.743 0.744 0.745 0.746 0.747 0.748 0.749 0.75  0.751 0.752 0.753
#  0.754 0.755 0.756 0.757 0.758 0.759 0.76  0.761 0.762 0.763 0.764 0.765
#  0.766 0.767 0.768 0.769 0.77  0.771 0.772 0.773 0.774 0.775 0.776 0.777
#  0.778 0.779 0.78  0.781 0.782 0.783 0.784 0.785 0.786 0.787 0.788 0.789
#  0.79  0.791 0.792 0.793 0.794 0.795 0.796 0.797 0.798 0.799 0.8   0.801
#  0.802 0.803 0.804 0.805 0.806 0.807 0.808 0.809 0.81  0.811 0.812 0.813
#  0.814 0.815 0.816 0.817 0.818 0.819 0.82  0.821 0.822 0.823 0.824 0.825
#  0.826 0.827 0.828 0.829 0.83  0.831 0.832 0.833 0.834 0.835 0.836 0.837
#  0.838 0.839 0.84  0.841 0.842 0.843 0.844 0.845 0.846 0.847 0.848 0.849
#  0.85  0.851 0.852 0.853 0.854 0.855 0.856 0.857 0.858 0.859 0.86  0.861
#  0.862 0.863 0.864 0.865 0.866 0.867 0.868 0.869 0.87  0.871 0.872 0.873
#  0.874 0.875 0.876 0.877 0.878 0.879 0.88  0.881 0.882 0.883 0.884 0.885
#  0.886 0.887 0.888 0.889 0.89  0.891 0.892 0.893 0.894 0.895 0.896 0.897
#  0.898 0.899 0.9   0.901 0.902 0.903 0.904 0.905 0.906 0.907 0.908 0.909
#  0.91  0.911 0.912 0.913 0.914 0.915 0.916 0.917 0.918 0.919 0.92  0.921
#  0.922 0.923 0.924 0.925 0.926 0.927 0.928 0.929 0.93  0.931 0.932 0.933
#  0.934 0.935 0.936 0.937 0.938 0.939 0.94  0.941 0.942 0.943 0.944 0.945
#  0.946 0.947 0.948 0.949 0.95  0.951 0.952 0.953 0.954 0.955 0.956 0.957
#  0.958 0.959 0.96  0.961 0.962 0.963 0.964 0.965 0.966 0.967 0.968 0.969
#  0.97  0.971 0.972 0.973 0.974 0.975 0.976 0.977 0.978 0.979 0.98  0.981
#  0.982 0.983 0.984 0.985 0.986 0.987 0.988 0.989 0.99  0.991 0.992 0.993
#  0.994 0.995 0.996 0.997 0.998 0.999]
# best param  0.07199999999999994
# best score  0.4913294797687861

# %%
# Initialiser une liste pour stocker les résultats de chaque combinaison de méthodes
results = []



max_algo_iter = len(vectorizers)*len(classifiers)*len(cleaners)
current_iter = 0

# Pour chaque combinaison de méthodes de vectorisation, de classification et de nettoyage de données
for vec in vectorizers:
    for clf in classifiers:
        for cleaner in cleaners:
            current_iter += 1
            print("===")
            print("iter number "+str(current_iter)+" sur "+str(max_algo_iter))
            print('vectorizer: '+ vec.__class__.__name__+ "\n"+
            'classifier: '+ clf.__class__.__name__+ "\n"+
            'cleaner: '+ cleaner.__name__)
            print("---")
            # Appliquer la méthode de nettoyage de données aux données d'entraînement et de test
            X_train_cleaned = [cleaner(sentence) for sentence in X_train]
            X_test_cleaned = [cleaner(sentence) for sentence in X_test]

            # Convertir les phrases en vecteurs en utilisant la méthode de vectorisation
            X_train_vec = vec.fit_transform(X_train_cleaned)
            X_test_vec = vec.transform(X_test_cleaned)

            # Entraîner un modèle de classification sur les données d'entraînement
            clf.fit(X_train_vec, y_train)

            # Prédire les étiquettes pour les données de test
            y_pred = clf.predict(X_test_vec)

            # Calculer la précision du modèle sur les données de test
            accuracy = accuracy_score(y_test, y_pred)

            precision = precision_score(y_test,y_pred,average="macro")

            # Ajouter les résultats à la liste de résultats
            results.append({
                'vectorizer': vec.__class__.__name__,
                'classifier': clf.__class__.__name__,
                'cleaner': cleaner.__name__,
                'accuracy': accuracy,
                "precision": precision
            })

# Trier les résultats par précision décroissante
results.sort(key=lambda x: x['accuracy'], reverse=True)

# Afficher les meilleurs résultats
print("Best results:")
for result in results[:5]:
    print("Vectorizer:", result['vectorizer'])
    print("Classifier:", result['classifier'])
    print("Cleaner:", result['cleaner'])
    print("Accuracy:", result['accuracy'])
    print()
# Out:
# ===
# iter number 1 sur 1
# vectorizer: TfidfVectorizer
# classifier: LinearSVC
# cleaner: empty
# ---
# Best results:
# Vectorizer: TfidfVectorizer
# Classifier: LinearSVC
# Cleaner: empty
# Accuracy: 0.5982905982905983

# %% [markdown]
# GridSearchs

# %%
tfidf = TfidfVectorizer()
X_train_vec = tfidf.fit_transform(X_train)
X_test_vec = tfidf.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'alpha': np.arange(0.591,0.593,0.0001),
    "fit_prior":[True,False]
}



grid_search = GridSearchCV(MultinomialNB(),param_grid)

grid_search.fit(X_train_vec, y_train)

print("best params: ",grid_search.best_params_)
print("pécision :", grid_search.best_score_)
print("pécision avec test :", grid_search.score(X_test_vec,y_test))
# Out:
# best params:  {'alpha': 0.5912, 'fit_prior': True}
# pécision : 0.4419270350024127
# pécision avec test : 0.5157232704402516

# %%
# Out:
# Accuracy: 0.564%
# ACCURACY SCORE:
# 0.5641
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[86], line 44
#      42 clf.fit(X_train_vec, y_train) # training
#      43 y_pred = clf.predict(X_test_vec) # predicting
# ---> 44 print(clf._class.name_, accuracy_score(y_test, y_pred)) # evaluating
#
# AttributeError: 'LogisticRegression' object has no attribute '_class'

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[87], line 7
#       4 # The ensemble is a voting classifier that aggregates our three models
#       5 voting_clf = VotingClassifier(estimators=[('svm', svm_clf), ('log', log_clf), ('logc', logcv_clf)], voting='hard')
# ----> 7 voting_clf.fit(X_train_vec, y_train) # training
#       8 y_pred_voting = voting_clf.predict(X_test_vec) # predicting
#       9 accuracy_score(y_test, y_pred_voting) # evaluating
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\ensemble\_voting.py:292, in VotingClassifier.fit(self, X, y, sample_weight)
#     289 self.classes_ = self.le_.classes_
#     290 transformed_y = self.le_.transform(y)
# --> 292 return super().fit(X, transformed_y, sample_weight)
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\ensemble\_voting.py:74, in _BaseVoting.fit(self, X, y, sample_weight)
#      68 if (self.weights is not None and
#      69         len(self.weights) != len(self.estimators)):
#      70     raise ValueError('Number of `estimators` and weights must be equal'
#      71                      '; got %d weights, %d estimators'
#      72                      % (len(self.weights), len(self.estimators)))
# ---> 74 self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#      75         delayed(_fit_single_estimator)(
#      76                 clone(clf), X, y,
#      77                 sample_weight=sample_weight,
#      78                 message_clsname='Voting',
#      79                 message=self._log_message(names[idx],
#      80                                           idx + 1, len(clfs))
#      81         )
#      82         for idx, clf in enumerate(clfs) if clf != 'drop'
#      83     )
#      85 self.named_estimators_ = Bunch()
#      87 # Uses 'drop' as placeholder for dropped estimators
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\joblib\parallel.py:1044, in Parallel.__call__(self, iterable)
#    1041 if self.dispatch_one_batch(iterator):
#    1042     self._iterating = self._original_iterator is not None
# -> 1044 while self.dispatch_one_batch(iterator):
#    1045     pass
#    1047 if pre_dispatch == "all" or n_jobs == 1:
#    1048     # The iterable was consumed all at once by the above for loop.
#    1049     # No need to wait for async callbacks to trigger to
#    1050     # consumption.
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\joblib\parallel.py:859, in Parallel.dispatch_one_batch(self, iterator)
#     857     return False
#     858 else:
# --> 859     self._dispatch(tasks)
#     860     return True
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\joblib\parallel.py:777, in Parallel._dispatch(self, batch)
#     775 with self._lock:
#     776     job_idx = len(self._jobs)
# --> 777     job = self._backend.apply_async(batch, callback=cb)
#     778     # A job can complete so quickly than its callback is
#     779     # called before we get here, causing self._jobs to
#     780     # grow. To ensure correct results ordering, .insert is
#     781     # used (rather than .append) in the following line
#     782     self._jobs.insert(job_idx, job)
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\joblib\_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\joblib\parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\joblib\parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\utils\fixes.py:222, in _FuncWrapper.__call__(self, *args, **kwargs)
#     220 def __call__(self, *args, **kwargs):
#     221     with config_context(**self.config):
# --> 222         return self.function(*args, **kwargs)
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\ensemble\_base.py:39, in _fit_single_estimator(estimator, X, y, sample_weight, message_clsname, message)
#      37 else:
#      38     with _print_elapsed_time(message_clsname, message):
# ---> 39         estimator.fit(X, y)
#      40 return estimator
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\linear_model\_logistic.py:1887, in LogisticRegressionCV.fit(self, X, y, sample_weight)
#    1884 else:
#    1885     prefer = 'processes'
# -> 1887 fold_coefs_ = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#    1888                        **_joblib_parallel_args(prefer=prefer))(
#    1889     path_func(X, y, train, test, pos_class=label, Cs=self.Cs,
#    1890               fit_intercept=self.fit_intercept, penalty=self.penalty,
#    1891               dual=self.dual, solver=solver, tol=self.tol,
#    1892               max_iter=self.max_iter, verbose=self.verbose,
#    1893               class_weight=class_weight, scoring=self.scoring,
#    1894               multi_class=multi_class,
#    1895               intercept_scaling=self.intercept_scaling,
#    1896               random_state=self.random_state,
#    1897               max_squared_sum=max_squared_sum,
#    1898               sample_weight=sample_weight,
#    1899               l1_ratio=l1_ratio
#    1900               )
#    1901     for label in iter_encoded_labels
#    1902     for train, test in folds
#    1903     for l1_ratio in l1_ratios_)
#    1905 # _log_reg_scoring_path will output different shapes depending on the
#    1906 # multi_class param, so we need to reshape the outputs accordingly.
#    1907 # Cs is of shape (n_classes . n_folds . n_l1_ratios, n_Cs) and all the
#    (...)
#    1914 #  (n_classes, n_folds, n_Cs . n_l1_ratios) or
#    1915 #  (1, n_folds, n_Cs . n_l1_ratios)
#    1916 coefs_paths, Cs, scores, n_iter_ = zip(*fold_coefs_)
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\joblib\parallel.py:1044, in Parallel.__call__(self, iterable)
#    1041 if self.dispatch_one_batch(iterator):
#    1042     self._iterating = self._original_iterator is not None
# -> 1044 while self.dispatch_one_batch(iterator):
#    1045     pass
#    1047 if pre_dispatch == "all" or n_jobs == 1:
#    1048     # The iterable was consumed all at once by the above for loop.
#    1049     # No need to wait for async callbacks to trigger to
#    1050     # consumption.
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\joblib\parallel.py:859, in Parallel.dispatch_one_batch(self, iterator)
#     857     return False
#     858 else:
# --> 859     self._dispatch(tasks)
#     860     return True
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\joblib\parallel.py:777, in Parallel._dispatch(self, batch)
#     775 with self._lock:
#     776     job_idx = len(self._jobs)
# --> 777     job = self._backend.apply_async(batch, callback=cb)
#     778     # A job can complete so quickly than its callback is
#     779     # called before we get here, causing self._jobs to
#     780     # grow. To ensure correct results ordering, .insert is
#     781     # used (rather than .append) in the following line
#     782     self._jobs.insert(job_idx, job)
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\joblib\_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\joblib\parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\joblib\parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\utils\fixes.py:222, in _FuncWrapper.__call__(self, *args, **kwargs)
#     220 def __call__(self, *args, **kwargs):
#     221     with config_context(**self.config):
# --> 222         return self.function(*args, **kwargs)
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\linear_model\_logistic.py:966, in _log_reg_scoring_path(X, y, train, test, pos_class, Cs, scoring, fit_intercept, max_iter, tol, class_weight, verbose, solver, penalty, dual, intercept_scaling, multi_class, random_state, max_squared_sum, sample_weight, l1_ratio)
#     963     sample_weight = _check_sample_weight(sample_weight, X)
#     964     sample_weight = sample_weight[train]
# --> 966 coefs, Cs, n_iter = _logistic_regression_path(
#     967     X_train, y_train, Cs=Cs, l1_ratio=l1_ratio,
#     968     fit_intercept=fit_intercept, solver=solver, max_iter=max_iter,
#     969     class_weight=class_weight, pos_class=pos_class,
#     970     multi_class=multi_class, tol=tol, verbose=verbose, dual=dual,
#     971     penalty=penalty, intercept_scaling=intercept_scaling,
#     972     random_state=random_state, check_input=False,
#     973     max_squared_sum=max_squared_sum, sample_weight=sample_weight)
#     975 log_reg = LogisticRegression(solver=solver, multi_class=multi_class)
#     977 # The score method of Logistic Regression has a classes_ attribute.
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\linear_model\_logistic.py:758, in _logistic_regression_path(X, y, pos_class, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, class_weight, dual, penalty, intercept_scaling, multi_class, random_state, check_input, max_squared_sum, sample_weight, l1_ratio)
#     755 if solver == 'lbfgs':
#     756     iprint = [-1, 50, 1, 100, 101][
#     757         np.searchsorted(np.array([0, 1, 2, 3]), verbose)]
# --> 758     opt_res = optimize.minimize(
#     759         func, w0, method="L-BFGS-B", jac=True,
#     760         args=(X, target, 1. / C, sample_weight),
#     761         options={"iprint": iprint, "gtol": tol, "maxiter": max_iter}
#     762     )
#     763     n_iter_i = _check_optimize_result(
#     764         solver, opt_res, max_iter,
#     765         extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
#     766     w0, loss = opt_res.x, opt_res.fun
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\scipy\optimize\_minimize.py:619, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     616     return _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     617                               **options)
#     618 elif meth == 'l-bfgs-b':
# --> 619     return _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     620                             callback=callback, **options)
#     621 elif meth == 'tnc':
#     622     return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     623                          **options)
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\scipy\optimize\lbfgsb.py:360, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     354 task_str = task.tobytes()
#     355 if task_str.startswith(b'FG'):
#     356     # The minimization routine wants f and g at the current x.
#     357     # Note that interruptions due to maxfun are postponed
#     358     # until the completion of the current minimization iteration.
#     359     # Overwrite f and g:
# --> 360     f, g = func_and_grad(x)
#     361 elif task_str.startswith(b'NEW_X'):
#     362     # new iteration
#     363     n_iterations += 1
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\scipy\optimize\_differentiable_functions.py:260, in ScalarFunction.fun_and_grad(self, x)
#     258 if not np.array_equal(x, self.x):
#     259     self._update_x_impl(x)
# --> 260 self._update_fun()
#     261 self._update_grad()
#     262 return self.f, self.g
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\scipy\optimize\_differentiable_functions.py:226, in ScalarFunction._update_fun(self)
#     224 def _update_fun(self):
#     225     if not self.f_updated:
# --> 226         self._update_fun_impl()
#     227         self.f_updated = True
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\scipy\optimize\_differentiable_functions.py:133, in ScalarFunction.__init__.<locals>.update_fun()
#     132 def update_fun():
# --> 133     self.f = fun_wrapped(self.x)
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\scipy\optimize\_differentiable_functions.py:130, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     128 def fun_wrapped(x):
#     129     self.nfev += 1
# --> 130     return fun(x, *args)
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\scipy\optimize\optimize.py:74, in MemoizeJac.__call__(self, x, *args)
#      72 def __call__(self, x, *args):
#      73     """ returns the the function value """
# ---> 74     self._compute_if_needed(x, *args)
#      75     return self._value
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\scipy\optimize\optimize.py:68, in MemoizeJac._compute_if_needed(self, x, *args)
#      66 if not np.all(x == self.x) or self._value is None or self.jac is None:
#      67     self.x = np.asarray(x).copy()
# ---> 68     fg = self.fun(x, *args)
#      69     self.jac = fg[1]
#      70     self._value = fg[0]
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\linear_model\_logistic.py:736, in _logistic_regression_path.<locals>.func(x, *args)
# --> 736 def func(x, *args): return _multinomial_loss_grad(x, *args)[0:2]
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\linear_model\_logistic.py:351, in _multinomial_loss_grad(w, X, Y, alpha, sample_weight)
#     349 sample_weight = sample_weight[:, np.newaxis]
#     350 diff = sample_weight * (p - Y)
# --> 351 grad[:, :n_features] = safe_sparse_dot(diff.T, X)
#     352 grad[:, :n_features] += alpha * w
#     353 if fit_intercept:
#
# KeyboardInterrupt:

# %% [markdown]
# FASTTEXT

# %%
X_train_fast = [" ".join(fasttext.tokenize(sentence)) for sentence in X_train]
X_test_fast = [" ".join(fasttext.tokenize(sentence)) for sentence in X_test]

model_fast = fasttext.load_model("../cc.fr.300.bin")
#linSVC = LinearSVC()
#linSVC.fit(X_train_fast,y_train)


y_pred = model_fast.predict(X_test_fast)

print("precision: ",accuracy_score(y_test,y_pred))
# Out:
# ['Cela fait partie de sa vie sociale.', 'Les quelques chiffres publiés à ce jour donnent une idée de la dégradation du climat entre les élèves des deux sexes.', "Soixante associations de défense de l'environnement et de solidarité sociale ont mis en garde contre une possible exclusion de l'obligation de rénovation énergétique des logements dans la future loi sur le climat.", '"Friendly" pour "Amicalement" est tout simplement un non-sens', 'En conduisant un véhicule, vous ne pouvez pas téléphoner.', "Quand je reviendrai, j'offrirai beaucoup d'amour à ceux que j'aprécie et je couvrirai mes enfants de présents.", 'Que les marquis se taisent sur leurs bancs, ou bien je fais tâter ma canne à leurs rubans !', 'Je ne pourrai pas venir demain.', 'Tu dois te couper les ongles.', 'Plus grave, un lien a été mis en évidence entre ces usages et des symptômes de dépression.', "Je vais à l'école pendant la journée. Mon père s'appelle Alain.", "Cependant, les bougies de l'orchestre s'allumèrent; le lustre descendit du plafond, versant, avec le rayonnement de ses facettes, une gaieté subite dans la salle; puis les musiciens entrèrent les uns après les autres, et ce fut d'abord un long charivari de basses ronflant, de violons grinçant, de pistons trompétant, de flûtes et de flageolets qui piaulaient.", "Nous avons l'habitude d'acheter quinze pommes, ce sont elles qui les comptent et les mettent dans notre panier.", "D'autres auteurs ont exploité ce terrain comme Erik Orsenna et ses Chevaliers du subjonctif, sorti à l'automne 2004 (Le Monde de l'éducation n° 328, septembre 2004)", "Si l'individualisme repose sur le culte de chacun pour soi, l'individualisation correspond à une culture du choix, chacun affirmant son autonomie, sa capacité d'orienter son action sans être contrôlé ou contraint.", "Elle prendra un pseudonyme masculin pour poursuivre ses travaux qui, revisités il y a peu, ont montré qu'elle avait imaginé les prémisses des travaux de Poincaré.", "La première modernité a inventé l'universalisme abstrait, qui définissait tout ce que les individus ont en commun.", 'Quand il arriva près de la maison il vit un monsieur à la porte, et il entendit qu\'il disait à la femme : "Ma bonne femme, votre mari est-il chez lui ?" "Non monsieur," répondit la femme.', "Mes parents disent que l'île est très jolie : il y a de très belles plages, on va pouvoir nager.", 'Il goûta cette sauce aussitôt que tu la eus préparée.', 'Je me demande si les fourmis dorment.', "La Fête des mères est un jour très spécial durant lequel les mamans sont mises à l'honneur.", "Quand les clients viennent, on a l'impression qu'ils viennent dans un endroit féerique", "Il a plu et j'ai attendu l'autobus.", "C'est aussi un test pour les couples nouvellement formés ou qui n'avaient jamais expérimenté la vie à deux.", "J'ai eu un week-end un peu spécial.", "Les occasions d'opposition, dues aux différences de culture, sont plus nombreuses.", 'Le 1er mai correspond à la fête du Travail, et rappelle la lutte des ouvriers pour réduire la journée de travail à huit heures.', "Giscard se laisse filmer durant ses vacances à la montagne ou à la plage, il apparaît en short, puis torse nu lors d'un match de football organisé entre notables de Chamalières, village dont il fut longtemps le maire", 'Or peut-on se contenter de cette expérience immédiate ou pour reprendre la formulation de Bergson, de cette "donnée immédiate de la conscience"', "Ainsi l'abbé Blanès n'avait pas communiqué sa science assez difficile à Fabrice ; mais, à son insu, il lui avait inoculé une confiance illimitée dans les signes qui peuvent prédire l'avenir.", 'À la semaine prochaine.', "En Suisse les personnes physiques peuvent être assujetties à l'impôt sur le revenu et la fortune en raison de leurs liens personnels ou leur rattachement économique avec la Suisse.", 'Si vous aviez cherché ces dossiers, vous les auriez trouvés.', 'Tu mangeas les petits fruits dès que tu les eus cueillis', 'Si vous en avez la possibilité,  ...
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[150], line 10
#       5 model_fast = fasttext.load_model("../cc.fr.300.bin")
#       6 #linSVC = LinearSVC()
#       7 #linSVC.fit(X_train_fast,y_train)
# ---> 10 y_pred = model_fast.predict(X_test_fast)
#      12 print("precision: ",accuracy_score(y_test,y_pred))
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\fasttext\FastText.py:220, in _FastText.predict(self, text, k, threshold, on_unicode_error)
#     218 if type(text) == list:
#     219     text = [check(entry) for entry in text]
# --> 220     all_labels, all_probs = self.f.multilinePredict(
#     221         text, k, threshold, on_unicode_error)
#     223     return all_labels, all_probs
#     224 else:
#
# ValueError: Model needs to be supervised for prediction!

# %% [markdown]
# Return to CSV

# %%
from sklearn.pipeline import Pipeline

pipeline = Pipeline([
    ('vectorizer', TfidfVectorizer()),
    ('classifier', LinearSVC())
])

# Définition de la grille de recherche des hyperparamètres
param_grid = {
    'vectorizer__ngram_range': [(1, 1), (1, 2), (1, 3)],
    'vectorizer__min_df': [2, 3, 4],
    'vectorizer__max_df': [0.9, 0.95, 1.0],
    'vectorizer__max_features': [1000, 2000, 3000],
    'classifier__C': [0.1, 1, 10]
}

# Création de l'objet GridSearchCV
grid_search = GridSearchCV(pipeline, param_grid, cv=5)

# Entraînement du modèle sur les données d'entraînement
grid_search.fit(X_train, y_train)

# Prédiction des étiquettes pour les données de test
predictions = grid_search.predict(X_test)

# Calcul de la précision du modèle
accuracy = accuracy_score(y_test, predictions)
print("Précision:", accuracy)

# Affichage des meilleurs hyperparamètres trouvés par la grille de recherche
print("Meilleurs hyperparamètres:", grid_search.best_params_)
# Out:
# Précision: 0.45
# Meilleurs hyperparamètres: {'classifier__C': 0.1, 'vectorizer__max_df': 0.9, 'vectorizer__max_features': 3000, 'vectorizer__min_df': 2, 'vectorizer__ngram_range': (1, 1)}

# %%
unlabelled_test_data = pd.read_csv("../data/unlabelled_test_data.csv")
unlabelled_test_data_tfidf = tfidf.transform(unlabelled_test_data["sentence"])
linSVC = LinearSVC().fit(X_train_vec,y_train)
y_pred = linSVC.predict(unlabelled_test_data_tfidf)



unlabelled_test_data["difficulty"] = y_pred

unlabelled_test_data["difficulty"] = labelencoder.inverse_transform(y_pred)

unlabelled_test_data.drop(columns=["sentence"],inplace=True)

unlabelled_test_data.to_csv("../data/submit9.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 4
#       2 unlabelled_test_data_tfidf = tfidf.transform(unlabelled_test_data["sentence"])
#       3 linSVC = LinearSVC().fit(X_train_vec,y_train)
# ----> 4 y_pred = linSVC.predict(unlabelled_test_data["sentence"])
#       8 unlabelled_test_data["difficulty"] = y_pred
#      10 unlabelled_test_data["difficulty"] = labelencoder.inverse_transform(y_pred)
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\linear_model\_base.py:309, in LinearClassifierMixin.predict(self, X)
#     295 def predict(self, X):
#     296     """
#     297     Predict class labels for samples in X.
#     298
#    (...)
#     307         Predicted class label per sample.
#     308     """
# --> 309     scores = self.decision_function(X)
#     310     if len(scores.shape) == 1:
#     311         indices = (scores > 0).astype(int)
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\linear_model\_base.py:284, in LinearClassifierMixin.decision_function(self, X)
#     264 """
#     265 Predict confidence scores for samples.
#     266
#    (...)
#     280     class would be predicted.
#     281 """
#     282 check_is_fitted(self)
# --> 284 X = check_array(X, accept_sparse='csr')
#     286 n_features = self.coef_.shape[1]
#     287 if X.shape[1] != n_features:
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\utils\validation.py:63, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      61 extra_args = len(args) - len(all_args)
#      62 if extra_args <= 0:
# ---> 63     return f(*args, **kwargs)
#      65 # extra_args > 0
#      66 args_msg = ['{}={}'.format(name, arg)
#      67             for name, arg in zip(kwonly_args[:extra_args],
#      68                                  args[-extra_args:])]
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\sklearn\utils\validation.py:673, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     671         array = array.astype(dtype, casting="unsafe", copy=False)
#     672     else:
# --> 673         array = np.asarray(array, order=order, dtype=dtype)
#     674 except ComplexWarning as complex_warning:
#     675     raise ValueError("Complex data not supported\n"
#     676                      "{}\n".format(array)) from complex_warning
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\numpy\core\_asarray.py:102, in asarray(a, dtype, order, like)
#      99 if like is not None:
#     100     return _asarray_with_like(a, dtype=dtype, order=order, like=like)
# --> 102 return array(a, dtype, copy=False, order=order)
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\pandas\core\series.py:768, in Series.__array__(self, dtype)
#     721 def __array__(self, dtype=None) -> np.ndarray:
#     722     """
#     723     Return the values as a NumPy array.
#     724
#    (...)
#     766           dtype='datetime64[ns]')
#     767     """
# --> 768     return np.asarray(self.array, dtype)
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\numpy\core\_asarray.py:102, in asarray(a, dtype, order, like)
#      99 if like is not None:
#     100     return _asarray_with_like(a, dtype=dtype, order=order, like=like)
# --> 102 return array(a, dtype, copy=False, order=order)
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\pandas\core\arrays\numpy_.py:203, in PandasArray.__array__(self, dtype)
#     202 def __array__(self, dtype=None) -> np.ndarray:
# --> 203     return np.asarray(self._ndarray, dtype=dtype)
#
# File c:\wamp64\www\demo_rdf\venv\lib\site-packages\numpy\core\_asarray.py:102, in asarray(a, dtype, order, like)
#      99 if like is not None:
#     100     return _asarray_with_like(a, dtype=dtype, order=order, like=like)
# --> 102 return array(a, dtype, copy=False, order=order)
#
# ValueError: could not convert string to float: 'Nous dûmes nous excuser des propos que nous eûmes prononcés'
